# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torchvision.utils import save_image
import matplotlib.pyplot as plt

# %%
# Set hyperparameters
EPOCHS = 500
BATCH_SIZE = 100
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print("다음 장치를 사용합니다 : ", DEVICE)
# Out:
# 다음 장치를 사용합니다 :  cuda

# %%
# Get dataset
trainset = datasets.FashionMNIST('./.data',
    train=True,
    download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ])
)
train_loader = torch.utils.data.DataLoader(
    dataset=trainset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

# %%
# generator
G = nn.Sequential(
    nn.Linear(64, 256),
    nn.ReLU(),
    nn.Linear(256, 256),
    nn.ReLU(),
    nn.Linear(256, 784),
    nn.Tanh() # -1 < result < 1
)

# %%
# discriminator
D = nn.Sequential(
    nn.Linear(784, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 1),
    nn.Sigmoid() # sigmoid -> real or fake
)

# %%
# Implementation
D = D.to(DEVICE)
G = G.to(DEVICE)

criterion = nn.BCELoss()
d_optimizer = optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = optim.Adam(G.parameters(), lr=0.0002)

# %%
total_step = len(train_loader)
for epoch in range(EPOCHS):
    for i, (images, _) in enumerate(train_loader):
        images = images.reshape(BATCH_SIZE, -1).to(DEVICE)
        
        real_labels = torch.ones(BATCH_SIZE, 1).to(DEVICE)
        fake_labels = torch.zeros(BATCH_SIZE, 1).to(DEVICE)
        
        # 판별자에서 진짜에 대한 값 계산
        outputs = D(images)
        d_loss_real = criterion(outputs, real_labels)
        real_score = outputs
        
        z = torch.randn(BATCH_SIZE, 64).to(DEVICE)
        fake_images = G(z)
        
        # 판별자에서 가짜에 대한 값 계산
        outputs = D(fake_images)
        d_loss_fake = criterion(outputs, fake_labels)
        fake_score = outputs
        
        # learning discriminator
        d_loss = d_loss_real + d_loss_fake
        
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()
        
        # learning generator
        fake_images = G(z)
        outputs = D(fake_images)
        g_loss = criterion(outputs, real_labels)
        
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        g_loss.backward()
        g_optimizer.step()
        
    print('epoch [{}/{}] d_loss:{:.4f} g_loss:{:.4f} D(x):{:.2f} D(G(z)):{:.2f}'
    .format(epoch, EPOCHS, d_loss.item(), g_loss.item(), real_score.mean().item(), fake_score.mean().item()))
# Out:
# epoch [0/500] d_loss:0.0479 g_loss:5.1707 D(x):0.98 D(G(z)):0.02
# epoch [1/500] d_loss:0.0322 g_loss:4.4349 D(x):0.99 D(G(z)):0.02
# epoch [2/500] d_loss:0.0185 g_loss:7.3561 D(x):1.00 D(G(z)):0.01
# epoch [3/500] d_loss:0.0155 g_loss:7.7072 D(x):0.99 D(G(z)):0.01
# epoch [4/500] d_loss:0.0487 g_loss:5.3951 D(x):0.98 D(G(z)):0.02
# epoch [5/500] d_loss:0.1227 g_loss:5.3373 D(x):0.97 D(G(z)):0.04
# epoch [6/500] d_loss:0.2757 g_loss:3.0606 D(x):0.91 D(G(z)):0.06
# epoch [7/500] d_loss:0.1307 g_loss:4.4753 D(x):0.94 D(G(z)):0.02
# epoch [8/500] d_loss:0.1284 g_loss:6.1769 D(x):0.97 D(G(z)):0.02
# epoch [9/500] d_loss:0.3016 g_loss:3.0754 D(x):0.95 D(G(z)):0.16
# epoch [10/500] d_loss:0.2296 g_loss:3.9922 D(x):0.94 D(G(z)):0.10
# epoch [11/500] d_loss:0.2658 g_loss:3.5925 D(x):0.94 D(G(z)):0.09
# epoch [12/500] d_loss:0.3978 g_loss:4.3474 D(x):0.95 D(G(z)):0.21
# epoch [13/500] d_loss:0.1894 g_loss:4.0140 D(x):0.94 D(G(z)):0.07
# epoch [14/500] d_loss:0.3014 g_loss:3.2506 D(x):0.87 D(G(z)):0.09
# epoch [15/500] d_loss:0.3627 g_loss:3.0257 D(x):0.87 D(G(z)):0.09
# epoch [16/500] d_loss:0.4437 g_loss:4.4797 D(x):0.85 D(G(z)):0.09
# epoch [17/500] d_loss:0.7846 g_loss:4.3364 D(x):0.76 D(G(z)):0.07
# epoch [18/500] d_loss:0.6389 g_loss:2.9879 D(x):0.80 D(G(z)):0.12
# epoch [19/500] d_loss:0.2551 g_loss:4.0596 D(x):0.92 D(G(z)):0.07
# epoch [20/500] d_loss:0.3428 g_loss:4.2442 D(x):0.86 D(G(z)):0.06
# epoch [21/500] d_loss:0.2463 g_loss:4.1136 D(x):0.93 D(G(z)):0.10
# epoch [22/500] d_loss:0.1882 g_loss:3.6973 D(x):0.96 D(G(z)):0.10
# epoch [23/500] d_loss:0.2835 g_loss:3.2123 D(x):0.92 D(G(z)):0.13
# epoch [24/500] d_loss:0.3666 g_loss:3.0345 D(x):0.88 D(G(z)):0.11
# epoch [25/500] d_loss:0.2386 g_loss:3.7826 D(x):0.91 D(G(z)):0.09
# epoch [26/500] d_loss:0.3427 g_loss:3.6694 D(x):0.89 D(G(z)):0.10
# epoch [27/500] d_loss:0.4834 g_loss:3.2662 D(x):0.90 D(G(z)):0.20
# epoch [28/500] d_loss:0.5474 g_loss:2.5674 D(x):0.87 D(G(z)):0.17
# epoch [29/500] d_loss:0.4702 g_loss:3.3584 D(x):0.88 D(G(z)):0.17
# epoch [30/500] d_loss:0.6427 g_loss:3.1752 D(x):0.81 D(G(z)):0.17
# epoch [31/500] d_loss:0.5992 g_loss:2.5939 D(x):0.83 D(G(z)):0.16
# epoch [32/500] d_loss:0.4540 g_loss:3.2022 D(x):0.85 D(G(z)):0.13
# epoch [33/500] d_loss:0.4598 g_loss:3.3155 D(x):0.85 D(G(z)):0.14
# epoch [34/500] d_loss:0.5250 g_loss:2.8916 D(x):0.80 D(G(z)):0.14
# epoch [35/500] d_loss:0.6587 g_loss:2.2816 D(x):0.82 D(G(z)):0.20
# epoch [36/500] d_loss:0.5018 g_loss:2.8291 D(x):0.83 D(G(z)):0.12
# epoch [37/500] d_loss:0.7263 g_loss:2.1923 D(x):0.78 D(G(z)):0.20
# epoch [38/500] d_loss:0.4948 g_loss:3.9397 D(x):0.78 D(G(z)):0.06
# epoch [39/500] d_loss:0.6348 g_loss:2.9565 D(x):0.83 D(G(z)):0.23
# epoch [40/500] d_loss:0.6262 g_loss:2.4167 D(x):0.81 D(G(z)):0.20
# epoch [41/500] d_loss:0.5909 g_loss:3.2815 D(x):0.73 D(G(z)):0.07
# epoch [42/500] d_loss:0.5407 g_loss:3.2776 D(x):0.86 D(G(z)):0.18
# epoch [43/500] d_loss:0.7818 g_loss:2.3118 D(x):0.78 D(G(z)):0.21
# epoch [44/500] d_loss:0.6327 g_loss:2.5176 D(x):0.81 D(G(z)):0.22
# epoch [45/500] d_loss:0.6813 g_loss:3.1031 D(x):0.83 D(G(z)):0.21
# epoch [46/500] d_loss:0.4817 g_loss:2.4470 D(x):0.89 D(G(z)):0.21
# epoch [47/500] d_loss:0.6092 g_loss:2.0613 D(x):0.77 D(G(z)):0.14
# epoch [48/500] d_loss:0.7156 g_loss:1.9178 D(x):0.80 D(G(z)):0.23
# epoch [49/500] d_loss:0.5699 g_loss:2.6702 D(x):0.80 D(G(z)):0.15
# epoch [50/500] d_loss:0.5483 g_loss:3.2220 D(x):0.82 D(G(z)):0.15
# epoch [51/500] d_loss:0.5547 g_loss:3.1628 D(x):0.81 D(G(z)):0.16
# epoch [52/500] d_loss:0.5515 g_loss:2.3867 D(x):0.82 D(G(z)):0.16
# epoch [53/500] d_loss:0.6371 g_loss:1.9919 D(x):0.85 D(G(z)):0.26
# epoch [54/500] d_loss:0.8771 g_loss:2.1542 D(x):0.78 D(G(z)):0.28
# epoch [55/500] d_loss:0.7025 g_loss:2.7135 D(x):0.82 D(G(z)):0.25
# epoch [56/500] d_loss:0.4742 g_loss:2.5118 D(x):0.91 D(G(z)):0.23
# epoch [57/500] d_loss:0.5832 g_loss:2.7925 D(x):0.85 D(G(z)):0.22
# epoch [58/500] d_loss:0.4222 g_loss:2.7686 D(x):0.85 D(G(z)):0.12
# epoch [59/500] d_loss:0.6425 g_loss:2.5437 D(x):0.82 D(G(z)):0.23
# epoch [60/500] d_loss:0.5857 g_loss:2.8741 D(x):0.81 D(G(z)):0.17
# epoch [61/500] d_loss:0.7994 g_loss:2.0146 D(x):0.80 D(G(z)):0.32
# epoch [62/500] d_loss:0.7198 g_loss:2.2707 D(x):0.74 D(G(z)):0.21
# epoch [63/500] d_loss:0.6489 g_loss:2.4774 D(x):0.79 D(G(z)):0.18
# epoch [64/500] d_loss:0.9826 g_loss:1.4558 D(x):0.70 D(G(z)):0.28
# epoch [65/500] d_loss:1.0927 g_loss:1.8488 D(x):0.74 D(G(z)):0.36
# epoch [66/500] d_loss:0.8339 g_loss:2.9812 D(x):0.75 D(G(z)):0.24
# epoch [67/500] d_loss:0.7288 g_loss:2.6898 D(x):0.78 D(G(z)):0.21
# epoch [68/500] d_loss:0.5386 g_loss:2.8724 D(x):0.84 D(G(z)):0.18
# epoch [69/500] d_loss:0.5800 g_loss:2.3977 D(x):0.80 D(G(z)):0.18
# epoch [70/500] d_loss:0.7799 g_loss:1.9006 D(x):0.70 D(G(z)):0.22
# epoch [71/500] d_loss:0.6493 g_loss:2.8265 D(x):0.81 D(G(z)):0.22
# epoch [72/500] d_loss:0.6858 g_loss:1.9441 D(x):0.78 D(G(z)):0.23
# epoch [73/500] d_loss:0.7568 g_loss:2.2461 D(x):0.77 D(G(z)):0.23
# epoch [74/500] d_loss:0.6751 g_loss:2.8280 D(x):0.74 D(G(z)):0.14
# epoch [75/500] d_loss:0.7203 g_loss:1.8975 D(x):0.80 D(G(z)):0.26
# epoch [76/500] d_loss:0.9565 g_loss:2.4191 D(x):0.72 D(G(z)):0.20
# epoch [77/500] d_loss:1.0325 g_loss:2.0586 D(x):0.70 D(G(z)):0.32
# epoch [78/500] d_loss:0.9322 g_loss:1.8568 D(x):0.74 D(G(z)):0.32
# epoch [79/500] d_loss:0.7883 g_loss:2.0137 D(x):0.74 D(G(z)):0.24
# epoch [80/500] d_loss:0.7120 g_loss:2.1496 D(x):0.75 D(G(z)):0.22
# epoch [81/500] d_loss:0.6626 g_loss:1.6779 D(x):0.78 D(G(z)):0.25
# epoch [82/500] d_loss:1.0127 g_loss:2.2246 D(x):0.70 D(G(z)):0.25
# epoch [83/500] d_loss:0.8056 g_loss:2.2215 D(x):0.82 D(G(z)):0.32
# epoch [84/500] d_loss:0.7881 g_loss:1.9990 D(x):0.71 D(G(z)):0.23
# epoch [85/500] d_loss:0.7237 g_loss:2.0509 D(x):0.76 D(G(z)):0.24
# epoch [86/500] d_loss:0.6517 g_loss:2.1447 D(x):0.76 D(G(z)):0.20
# epoch [87/500] d_loss:0.7609 g_loss:2.5654 D(x):0.80 D(G(z)):0.25
# epoch [88/500] d_loss:0.6176 g_loss:2.2433 D(x):0.81 D(G(z)):0.23
# epoch [89/500] d_loss:0.8213 g_loss:1.9630 D(x):0.74 D(G(z)):0.26
# epoch [90/500] d_loss:0.7067 g_loss:2.0378 D(x):0.78 D(G(z)):0.26
# epoch [91/500] d_loss:0.9809 g_loss:1.8598 D(x):0.64 D(G(z)):0.25
# epoch [92/500] d_loss:0.9130 g_loss:1.7515 D(x):0.64 D(G(z)):0.20
# epoch [93/500] d_loss:0.8056 g_loss:1.7621 D(x):0.76 D(G(z)):0.29
# epoch [94/500] d_loss:0.9301 g_loss:1.7417 D(x):0.69 D(G(z)):0.28
# epoch [95/500] d_loss:0.7316 g_loss:2.1356 D(x):0.73 D(G(z)):0.21
# epoch [96/500] d_loss:0.7431 g_loss:1.9643 D(x):0.76 D(G(z)):0.25
# epoch [97/500] d_loss:0.7741 g_loss:1.8702 D(x):0.73 D(G(z)):0.25
# epoch [98/500] d_loss:0.6734 g_loss:1.8423 D(x):0.76 D(G(z)):0.25
# epoch [99/500] d_loss:0.8743 g_loss:1.7375 D(x):0.77 D(G(z)):0.35
# epoch [100/500] d_loss:0.9558 g_loss:1.6701 D(x):0.74 D(G(z)):0.33
# epoch [101/500] d_loss:0.9861 g_loss:2.0233 D(x):0.65 D(G(z)):0.24
# epoch [102/500] d_loss:0.7235 g_loss:2.1969 D(x):0.73 D(G(z)):0.21
# epoch [103/500] d_loss:1.1564 g_loss:1.6264 D(x):0.69 D(G(z)):0.38
# epoch [104/500] d_loss:0.9665 g_loss:1.8983 D(x):0.76 D(G(z)):0.34
# epoch [105/500] d_loss:0.8610 g_loss:1.5574 D(x):0.80 D(G(z)):0.39
# epoch [106/500] d_loss:0.8400 g_loss:1.9119 D(x):0.70 D(G(z)):0.25
# epoch [107/500] d_loss:0.9106 g_loss:1.9100 D(x):0.73 D(G(z)):0.29
# epoch [108/500] d_loss:0.6993 g_loss:2.3304 D(x):0.75 D(G(z)):0.22
# epoch [109/500] d_loss:0.9074 g_loss:1.7453 D(x):0.77 D(G(z)):0.32
# epoch [110/500] d_loss:1.0391 g_loss:1.6026 D(x):0.70 D(G(z)):0.35
# epoch [111/500] d_loss:1.1455 g_loss:1.4977 D(x):0.66 D(G(z)):0.33
# epoch [112/500] d_loss:0.9896 g_loss:1.3198 D(x):0.67 D(G(z)):0.29
# epoch [113/500] d_loss:1.0004 g_loss:1.6633 D(x):0.65 D(G(z)):0.27
# epoch [114/500] d_loss:0.8571 g_loss:1.7005 D(x):0.75 D(G(z)):0.31
# epoch [115/500] d_loss:0.6988 g_loss:2.0161 D(x):0.77 D(G(z)):0.25
# epoch [116/500] d_loss:0.9458 g_loss:1.6440 D(x):0.75 D(G(z)):0.36
# epoch [117/500] d_loss:0.7471 g_loss:1.9351 D(x):0.74 D(G(z)):0.25
# epoch [118/500] d_loss:0.8972 g_loss:1.6006 D(x):0.72 D(G(z)):0.32
# epoch [119/500] d_loss:0.8653 g_loss:1.9154 D(x):0.63 D(G(z)):0.21
# epoch [120/500] d_loss:0.9504 g_loss:1.4270 D(x):0.74 D(G(z)):0.36
# epoch [121/500] d_loss:1.0254 g_loss:1.1460 D(x):0.76 D(G(z)):0.41
# epoch [122/500] d_loss:0.9406 g_loss:1.6110 D(x):0.72 D(G(z)):0.33
# epoch [123/500] d_loss:0.9911 g_loss:1.6356 D(x):0.68 D(G(z)):0.29
# epoch [124/500] d_loss:1.0807 g_loss:1.2777 D(x):0.67 D(G(z)):0.36
# epoch [125/500] d_loss:0.9309 g_loss:1.6918 D(x):0.66 D(G(z)):0.26
# epoch [126/500] d_loss:0.8587 g_loss:1.3489 D(x):0.75 D(G(z)):0.34
# epoch [127/500] d_loss:0.9655 g_loss:1.7764 D(x):0.70 D(G(z)):0.30
# epoch [128/500] d_loss:0.8872 g_loss:1.7294 D(x):0.78 D(G(z)):0.34
# epoch [129/500] d_loss:0.9499 g_loss:1.7641 D(x):0.76 D(G(z)):0.36
# epoch [130/500] d_loss:0.9633 g_loss:1.3170 D(x):0.71 D(G(z)):0.34
# epoch [131/500] d_loss:1.0499 g_loss:1.2954 D(x):0.71 D(G(z)):0.40
# epoch [132/500] d_loss:0.9741 g_loss:1.1222 D(x):0.78 D(G(z)):0.41
# epoch [133/500] d_loss:0.7912 g_loss:1.5455 D(x):0.73 D(G(z)):0.29
# epoch [134/500] d_loss:1.0574 g_loss:1.7179 D(x):0.65 D(G(z)):0.31
# epoch [135/500] d_loss:0.8642 g_loss:1.6841 D(x):0.72 D(G(z)):0.29
# epoch [136/500] d_loss:0.9691 g_loss:1.4694 D(x):0.73 D(G(z)):0.35
# epoch [137/500] d_loss:0.8635 g_loss:1.5115 D(x):0.74 D(G(z)):0.33
# epoch [138/500] d_loss:1.0026 g_loss:1.6559 D(x):0.63 D(G(z)):0.26
# epoch [139/500] d_loss:0.8974 g_loss:1.4315 D(x):0.70 D(G(z)):0.32
# epoch [140/500] d_loss:1.0616 g_loss:1.2962 D(x):0.68 D(G(z)):0.38
# epoch [141/500] d_loss:1.1186 g_loss:1.4620 D(x):0.64 D(G(z)):0.35
# epoch [142/500] d_loss:1.0793 g_loss:1.3423 D(x):0.73 D(G(z)):0.40
# epoch [143/500] d_loss:1.0294 g_loss:1.6622 D(x):0.66 D(G(z)):0.31
# epoch [144/500] d_loss:0.9930 g_loss:1.6668 D(x):0.67 D(G(z)):0.32
# epoch [145/500] d_loss:1.1104 g_loss:1.6298 D(x):0.69 D(G(z)):0.37
# epoch [146/500] d_loss:1.0082 g_loss:1.6446 D(x):0.69 D(G(z)):0.32
# epoch [147/500] d_loss:0.9132 g_loss:1.6770 D(x):0.63 D(G(z)):0.25
# epoch [148/500] d_loss:0.9297 g_loss:1.7501 D(x):0.67 D(G(z)):0.28
# epoch [149/500] d_loss:0.9476 g_loss:1.3264 D(x):0.70 D(G(z)):0.33
# epoch [150/500] d_loss:0.9630 g_loss:1.4776 D(x):0.72 D(G(z)):0.36
# epoch [151/500] d_loss:1.1105 g_loss:1.5834 D(x):0.65 D(G(z)):0.34
# epoch [152/500] d_loss:1.2628 g_loss:1.4000 D(x):0.59 D(G(z)):0.34
# epoch [153/500] d_loss:1.0649 g_loss:1.4402 D(x):0.72 D(G(z)):0.39
# epoch [154/500] d_loss:1.0765 g_loss:1.3599 D(x):0.62 D(G(z)):0.33
# epoch [155/500] d_loss:1.1140 g_loss:1.4558 D(x):0.68 D(G(z)):0.38
# epoch [156/500] d_loss:0.9619 g_loss:1.2974 D(x):0.69 D(G(z)):0.34
# epoch [157/500] d_loss:0.9804 g_loss:1.2037 D(x):0.74 D(G(z)):0.41
# epoch [158/500] d_loss:0.8707 g_loss:1.6694 D(x):0.71 D(G(z)):0.31
# epoch [159/500] d_loss:1.1474 g_loss:1.5251 D(x):0.62 D(G(z)):0.36
# epoch [160/500] d_loss:0.9618 g_loss:1.4739 D(x):0.66 D(G(z)):0.32
# epoch [161/500] d_loss:0.9699 g_loss:1.3918 D(x):0.65 D(G(z)):0.31
# epoch [162/500] d_loss:1.1096 g_loss:1.3831 D(x):0.64 D(G(z)):0.35
# epoch [163/500] d_loss:0.9373 g_loss:1.4390 D(x):0.76 D(G(z)):0.40
# epoch [164/500] d_loss:1.1965 g_loss:1.3216 D(x):0.61 D(G(z)):0.37
# epoch [165/500] d_loss:1.2099 g_loss:1.1050 D(x):0.63 D(G(z)):0.42
# epoch [166/500] d_loss:0.9755 g_loss:1.7181 D(x):0.61 D(G(z)):0.25
# epoch [167/500] d_loss:0.9996 g_loss:1.4087 D(x):0.69 D(G(z)):0.35
# epoch [168/500] d_loss:1.0999 g_loss:1.3109 D(x):0.61 D(G(z)):0.33
# epoch [169/500] d_loss:1.1806 g_loss:1.4455 D(x):0.62 D(G(z)):0.34
# epoch [170/500] d_loss:1.0235 g_loss:1.3111 D(x):0.65 D(G(z)):0.33
# epoch [171/500] d_loss:1.0118 g_loss:1.5769 D(x):0.60 D(G(z)):0.27
# epoch [172/500] d_loss:1.0232 g_loss:1.4046 D(x):0.64 D(G(z)):0.32
# epoch [173/500] d_loss:1.0874 g_loss:1.2867 D(x):0.64 D(G(z)):0.37
# epoch [174/500] d_loss:0.7218 g_loss:1.8852 D(x):0.76 D(G(z)):0.25
# epoch [175/500] d_loss:0.9773 g_loss:1.2284 D(x):0.76 D(G(z)):0.40
# epoch [176/500] d_loss:1.0814 g_loss:1.5533 D(x):0.62 D(G(z)):0.31
# epoch [177/500] d_loss:1.1324 g_loss:1.2779 D(x):0.63 D(G(z)):0.37
# epoch [178/500] d_loss:0.9782 g_loss:1.3515 D(x):0.68 D(G(z)):0.35
# epoch [179/500] d_loss:0.8990 g_loss:1.4077 D(x):0.70 D(G(z)):0.32
# epoch [180/500] d_loss:0.9200 g_loss:1.5168 D(x):0.62 D(G(z)):0.25
# epoch [181/500] d_loss:1.2753 g_loss:1.1389 D(x):0.63 D(G(z)):0.43
# epoch [182/500] d_loss:1.0837 g_loss:1.3782 D(x):0.63 D(G(z)):0.34
# epoch [183/500] d_loss:0.9501 g_loss:1.4022 D(x):0.72 D(G(z)):0.33
# epoch [184/500] d_loss:1.1108 g_loss:1.2562 D(x):0.66 D(G(z)):0.39
# epoch [185/500] d_loss:0.9334 g_loss:1.5804 D(x):0.66 D(G(z)):0.30
# epoch [186/500] d_loss:1.1350 g_loss:1.3624 D(x):0.62 D(G(z)):0.36
# epoch [187/500] d_loss:1.0968 g_loss:1.4202 D(x):0.62 D(G(z)):0.33
# epoch [188/500] d_loss:1.1511 g_loss:1.5297 D(x):0.61 D(G(z)):0.34
# epoch [189/500] d_loss:1.1479 g_loss:1.3661 D(x):0.64 D(G(z)):0.39
# epoch [190/500] d_loss:1.0482 g_loss:1.4715 D(x):0.61 D(G(z)):0.30
# epoch [191/500] d_loss:0.8501 g_loss:1.3755 D(x):0.71 D(G(z)):0.32
# epoch [192/500] d_loss:0.8472 g_loss:1.5334 D(x):0.68 D(G(z)):0.29
# epoch [193/500] d_loss:0.7758 g_loss:1.9504 D(x):0.69 D(G(z)):0.24
# epoch [194/500] d_loss:1.1416 g_loss:1.4449 D(x):0.62 D(G(z)):0.35
# epoch [195/500] d_loss:1.1714 g_loss:1.2647 D(x):0.61 D(G(z)):0.36
# epoch [196/500] d_loss:1.1390 g_loss:1.2927 D(x):0.63 D(G(z)):0.38
# epoch [197/500] d_loss:1.0365 g_loss:1.5298 D(x):0.76 D(G(z)):0.41
# epoch [198/500] d_loss:1.1157 g_loss:1.4761 D(x):0.58 D(G(z)):0.31
# epoch [199/500] d_loss:0.9128 g_loss:1.5203 D(x):0.66 D(G(z)):0.30
# epoch [200/500] d_loss:1.1213 g_loss:1.2666 D(x):0.65 D(G(z)):0.40
# epoch [201/500] d_loss:0.9668 g_loss:1.4696 D(x):0.67 D(G(z)):0.31
# epoch [202/500] d_loss:1.1050 g_loss:1.1468 D(x):0.69 D(G(z)):0.44
# epoch [203/500] d_loss:1.0128 g_loss:1.4885 D(x):0.66 D(G(z)):0.32
# epoch [204/500] d_loss:0.8958 g_loss:1.4379 D(x):0.65 D(G(z)):0.29
# epoch [205/500] d_loss:0.8682 g_loss:1.4125 D(x):0.74 D(G(z)):0.35
# epoch [206/500] d_loss:1.2145 g_loss:1.2608 D(x):0.60 D(G(z)):0.38
# epoch [207/500] d_loss:1.2221 g_loss:1.2226 D(x):0.56 D(G(z)):0.32
# epoch [208/500] d_loss:1.0109 g_loss:1.3943 D(x):0.67 D(G(z)):0.34
# epoch [209/500] d_loss:1.0495 g_loss:1.4533 D(x):0.67 D(G(z)):0.35
# epoch [210/500] d_loss:1.0447 g_loss:1.4017 D(x):0.63 D(G(z)):0.33
# epoch [211/500] d_loss:1.1336 g_loss:1.4764 D(x):0.57 D(G(z)):0.31
# epoch [212/500] d_loss:0.9519 g_loss:1.4388 D(x):0.69 D(G(z)):0.32
# epoch [213/500] d_loss:0.9208 g_loss:1.2777 D(x):0.71 D(G(z)):0.35
# epoch [214/500] d_loss:0.9798 g_loss:1.6286 D(x):0.61 D(G(z)):0.26
# epoch [215/500] d_loss:0.9949 g_loss:1.4965 D(x):0.63 D(G(z)):0.30
# epoch [216/500] d_loss:1.2782 g_loss:1.1160 D(x):0.68 D(G(z)):0.45
# epoch [217/500] d_loss:0.9014 g_loss:1.5724 D(x):0.69 D(G(z)):0.31
# epoch [218/500] d_loss:0.7897 g_loss:1.4689 D(x):0.73 D(G(z)):0.30
# epoch [219/500] d_loss:0.8395 g_loss:1.6419 D(x):0.68 D(G(z)):0.27
# epoch [220/500] d_loss:1.0507 g_loss:1.2262 D(x):0.66 D(G(z)):0.37
# epoch [221/500] d_loss:0.9976 g_loss:1.3172 D(x):0.70 D(G(z)):0.37
# epoch [222/500] d_loss:0.9849 g_loss:1.3492 D(x):0.67 D(G(z)):0.34
# epoch [223/500] d_loss:1.2490 g_loss:1.0067 D(x):0.64 D(G(z)):0.43
# epoch [224/500] d_loss:1.0558 g_loss:1.3001 D(x):0.64 D(G(z)):0.35
# epoch [225/500] d_loss:1.0744 g_loss:1.3040 D(x):0.60 D(G(z)):0.32
# epoch [226/500] d_loss:1.1447 g_loss:1.2510 D(x):0.65 D(G(z)):0.39
# epoch [227/500] d_loss:1.4014 g_loss:1.0496 D(x):0.57 D(G(z)):0.43
# epoch [228/500] d_loss:1.2891 g_loss:1.3621 D(x):0.58 D(G(z)):0.37
# epoch [229/500] d_loss:1.0121 g_loss:1.4134 D(x):0.64 D(G(z)):0.33
# epoch [230/500] d_loss:1.1008 g_loss:1.2150 D(x):0.62 D(G(z)):0.36
# epoch [231/500] d_loss:0.8916 g_loss:1.2593 D(x):0.74 D(G(z)):0.38
# epoch [232/500] d_loss:0.8603 g_loss:1.6433 D(x):0.68 D(G(z)):0.30
# epoch [233/500] d_loss:1.2488 g_loss:1.2489 D(x):0.58 D(G(z)):0.37
# epoch [234/500] d_loss:1.0521 g_loss:1.3237 D(x):0.68 D(G(z)):0.37
# epoch [235/500] d_loss:0.8926 g_loss:1.5104 D(x):0.71 D(G(z)):0.33
# epoch [236/500] d_loss:1.2781 g_loss:1.0516 D(x):0.62 D(G(z)):0.43
# epoch [237/500] d_loss:0.9488 g_loss:1.6699 D(x):0.61 D(G(z)):0.25
# epoch [238/500] d_loss:1.0573 g_loss:1.3261 D(x):0.63 D(G(z)):0.33
# epoch [239/500] d_loss:1.1229 g_loss:1.2902 D(x):0.59 D(G(z)):0.33
# epoch [240/500] d_loss:0.9017 g_loss:1.6838 D(x):0.69 D(G(z)):0.29
# epoch [241/500] d_loss:0.7635 g_loss:1.4612 D(x):0.73 D(G(z)):0.29
# epoch [242/500] d_loss:1.0518 g_loss:1.1739 D(x):0.63 D(G(z)):0.36
# epoch [243/500] d_loss:1.1207 g_loss:1.2536 D(x):0.62 D(G(z)):0.37
# epoch [244/500] d_loss:1.1288 g_loss:1.1602 D(x):0.66 D(G(z)):0.42
# epoch [245/500] d_loss:1.0953 g_loss:1.3888 D(x):0.65 D(G(z)):0.37
# epoch [246/500] d_loss:0.9778 g_loss:1.4185 D(x):0.67 D(G(z)):0.33
# epoch [247/500] d_loss:0.9713 g_loss:1.3822 D(x):0.64 D(G(z)):0.32
# epoch [248/500] d_loss:1.1274 g_loss:1.3741 D(x):0.59 D(G(z)):0.32
# epoch [249/500] d_loss:0.9079 g_loss:1.5106 D(x):0.69 D(G(z)):0.32
# epoch [250/500] d_loss:1.4995 g_loss:1.2908 D(x):0.54 D(G(z)):0.41
# epoch [251/500] d_loss:0.8176 g_loss:1.4299 D(x):0.74 D(G(z)):0.32
# epoch [252/500] d_loss:1.3186 g_loss:1.2137 D(x):0.59 D(G(z)):0.40
# epoch [253/500] d_loss:1.2776 g_loss:1.1679 D(x):0.58 D(G(z)):0.38
# epoch [254/500] d_loss:0.9058 g_loss:1.4568 D(x):0.69 D(G(z)):0.32
# epoch [255/500] d_loss:1.3642 g_loss:0.9437 D(x):0.59 D(G(z)):0.46
# epoch [256/500] d_loss:1.3102 g_loss:1.1695 D(x):0.61 D(G(z)):0.42
# epoch [257/500] d_loss:1.1795 g_loss:1.1952 D(x):0.70 D(G(z)):0.42
# epoch [258/500] d_loss:1.1074 g_loss:1.1766 D(x):0.64 D(G(z)):0.38
# epoch [259/500] d_loss:0.9971 g_loss:1.4626 D(x):0.66 D(G(z)):0.33
# epoch [260/500] d_loss:0.9653 g_loss:1.3296 D(x):0.68 D(G(z)):0.34
# epoch [261/500] d_loss:0.9032 g_loss:1.5731 D(x):0.65 D(G(z)):0.29
# epoch [262/500] d_loss:1.2268 g_loss:1.3021 D(x):0.60 D(G(z)):0.36
# epoch [263/500] d_loss:0.9560 g_loss:1.1728 D(x):0.70 D(G(z)):0.38
# epoch [264/500] d_loss:1.0501 g_loss:1.2055 D(x):0.61 D(G(z)):0.34
# epoch [265/500] d_loss:1.1460 g_loss:1.1031 D(x):0.59 D(G(z)):0.37
# epoch [266/500] d_loss:1.3198 g_loss:1.3014 D(x):0.58 D(G(z)):0.39
# epoch [267/500] d_loss:1.0141 g_loss:1.3027 D(x):0.65 D(G(z)):0.36
# epoch [268/500] d_loss:0.9760 g_loss:1.2726 D(x):0.66 D(G(z)):0.34
# epoch [269/500] d_loss:0.8126 g_loss:1.5524 D(x):0.68 D(G(z)):0.27
# epoch [270/500] d_loss:0.8771 g_loss:1.4336 D(x):0.71 D(G(z)):0.32
# epoch [271/500] d_loss:0.8679 g_loss:1.3526 D(x):0.70 D(G(z)):0.31
# epoch [272/500] d_loss:1.2068 g_loss:1.1155 D(x):0.62 D(G(z)):0.41
# epoch [273/500] d_loss:0.7513 g_loss:1.4859 D(x):0.72 D(G(z)):0.29
# epoch [274/500] d_loss:0.9790 g_loss:1.2829 D(x):0.66 D(G(z)):0.34
# epoch [275/500] d_loss:0.9435 g_loss:1.4202 D(x):0.66 D(G(z)):0.32
# epoch [276/500] d_loss:0.8664 g_loss:1.3133 D(x):0.71 D(G(z)):0.34
# epoch [277/500] d_loss:0.9025 g_loss:1.6599 D(x):0.69 D(G(z)):0.31
# epoch [278/500] d_loss:1.3658 g_loss:1.0830 D(x):0.57 D(G(z)):0.42
# epoch [279/500] d_loss:1.2351 g_loss:1.2409 D(x):0.60 D(G(z)):0.39
# epoch [280/500] d_loss:1.1553 g_loss:1.1833 D(x):0.66 D(G(z)):0.42
# epoch [281/500] d_loss:1.0116 g_loss:1.3587 D(x):0.66 D(G(z)):0.33
# epoch [282/500] d_loss:0.8087 g_loss:1.4301 D(x):0.73 D(G(z)):0.31

# %%
# visualization
z = torch.randn(BATCH_SIZE, 64).to(DEVICE)
fake_images = G(z)
for i in range(10):
    fake_images_img = np.reshape(fake_images.data.cpu().numpy()[i], (28, 28))
    plt.imshow(fake_imgaes_img, cmap='gray')
    plt.show()
